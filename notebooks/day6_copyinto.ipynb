# %%
# %sql
-- Create table with BIGINT instead of INT
CREATE OR REPLACE TABLE bronze_copyinto (
    id       BIGINT,
    customer STRING,
    amount   DOUBLE,
    type     STRING,
    date     STRING
);

-- Now COPY INTO
COPY INTO bronze_copyinto
FROM '/Volumes/workspace/default/raw_transactions/'
FILEFORMAT = JSON
FORMAT_OPTIONS ('inferSchema' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true');

-- Check results
SELECT * FROM bronze_copyinto ORDER BY id;



COPY INTO bronze_copyinto
FROM '/Volumes/workspace/default/raw_transactions/'
FILEFORMAT = JSON
FORMAT_OPTIONS ('inferSchema' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true');

-- Check count — should still be 6!
SELECT COUNT(*) as total FROM bronze_copyinto;
